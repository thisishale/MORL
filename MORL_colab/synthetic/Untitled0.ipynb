# %%
# !pip install https://download.pytorch.org/whl/cu100/torch-1.0.0-cp36-cp36m-linux_x86_64.whl
# Out:
# ...
#      |████████████████████████████████| 753.6MB 24kB/s
# ERROR: torchvision 0.8.1+cu101 has requirement torch==1.7.0, but you'll have torch 1.0.0 which is incompatible.
# ...
#   Found existing installation: torch 1.7.0+cu101
#     Uninstalling torch-1.7.0+cu101:
#       Successfully uninstalled torch-1.7.0+cu101
# ...

# %%
import torch
torch.__version__
# Out:
# '1.0.0'

# %%
# !python /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/train.py --env-name ft --method crl-envelope --model linear --gamma  0.99 --mem-size 4000 --batch-size 256 --lr  1e-3 --epsilon 0.5 --epsilon-decay --weight-num 32 --episode-num 5000 --optimizer Adam --save /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/saved/ --log /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/logs/envelope_new_weight_32_2 --save-mean /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/mean --checkpoint /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/ckpt/ --update-freq 100 --beta 0.01 --name envelope_new_weight_32_2
# Out:
# Streaming output truncated to the last 5000 lines.
# 1977
# 0.01
# end of eps 1978 with total reward (1) 2.59, the Q is 8.09 | 6.77; loss: 0.3091
# 1978
# 0.01
# end of eps 1979 with total reward (1) 2.73, the Q is 8.09 | 6.77; loss: 0.3182
# 1979
# 0.01
# end of eps 1980 with total reward (1) 4.27, the Q is 8.09 | 6.77; loss: 0.3262
# 1980
# 0.01
# end of eps 1981 with total reward (1) 5.88, the Q is 8.09 | 6.77; loss: 0.3206
# 1981
# 0.01
# end of eps 1982 with total reward (1) 1.96, the Q is 8.09 | 6.77; loss: 0.3050
# 1982
# 0.01
# end of eps 1983 with total reward (1) 4.42, the Q is 8.09 | 6.77; loss: 0.3104
# 1983
# 0.01
# end of eps 1984 with total reward (1) 1.79, the Q is 8.78 | 6.52; loss: 0.3687
# 1984
# 0.01
# end of eps 1985 with total reward (1) 4.31, the Q is 8.78 | 6.52; loss: 0.3311
# 1985
# 0.01
# end of eps 1986 with total reward (1) 2.48, the Q is 8.78 | 6.52; loss: 0.3335
# 1986
# 0.01
# ...

# %%
# !python /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/train.py --env-name ft --method crl-envelope --model linear --serialize --gamma  0.99 --mem-size 4000 --batch-size 256 --lr  1e-3 --epsilon 0.5 --epsilon-decay --weight-num 32 --episode-num 5000 --optimizer Adam --save /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/saved/ --log /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/logs/envelope_new_weight_32_2 --save-mean /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/mean --checkpoint /content/drive/My\ Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/ckpt/ --update-freq 100 --beta 0.01 --name envelope_new_weight_32_2
# Out:
# blahblahblahblah
# /content/drive/My Drive/github/RL_code/multi_objective/MORL_changed/synthetic/crl/envelope/saved/
# 0.01
# tensor(1.3587, device='cuda:0')
# 3600
# end of eps 3600 with total reward (1) 5.58, the Q is 7.04 | 6.13; loss: 0.2265
# 3600
# 0.01
# tensor(1.2604, device='cuda:0')
# 3601
# end of eps 3601 with total reward (1) 4.45, the Q is 7.04 | 6.13; loss: 0.2101
# 3601
# 0.01
# tensor(1.2122, device='cuda:0')
# 3602
# end of eps 3602 with total reward (1) 3.10, the Q is 7.04 | 6.13; loss: 0.2020
# 3602
# 0.01
# tensor(1.1749, device='cuda:0')
# 3603
# end of eps 3603 with total reward (1) 0.86, the Q is 7.04 | 6.13; loss: 0.1958
# 3603
# 0.01
# tensor(1.1141, device='cuda:0')
# 3604
# end of eps 3604 with total reward (1) 1.88, the Q is 7.04 | 6.13; loss: 0.1857
# 3604
# 0.01
# end of eps 3605 with total reward (1) 0.57, the Q is 7.04 | 6.13; loss: 0.2146
# 3605
# 0.01
# end of eps 3606 with total reward (1) 2.48, the Q is 7.04 | 6.13; loss: 0.1939
# 3606
# 0.01
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/My\ Drive/github/RL_code/
# Out:
# MORL_old  multi_objective  policy_gradient_cartpole.ipynb  RL_loss

# %%
pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 7.5MB/s
# ...

# %%
import os 
os.path.exists('/content/drive/My Drive/github/RL_code/')
# Out:
# True

# %%
a = []
a.append(10)
a.append(1)
a.append(2)
a.append(3)
min(a)
# Out:
# 1
